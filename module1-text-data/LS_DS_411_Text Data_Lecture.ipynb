# %% [markdown]
# Lambda School Data Science
#
# *Unit 4, Sprint 1, Module 1*
#
# ---
# <h1 id="moduleTitle"> Natural Language Processing Introduction (Prepare)</h1>
#
# "Natural" meaning - not computer languages but spoken/written human languages. The hard thing about NLP is that human languages are far less structured or consistent than computer languages. This is perhaps the largest source of difficulty when trying to get computers to "understand" human languages. How do you get a machine to understand sarcasm, and irony, and synonyms, connotation, denotation, nuance, and tone of voice --all without it having lived a lifetime of experience for context? If you think about it, our human brains have been exposed to quite a lot of training data to help us interpret languages, and even then we misunderstand each other pretty frequently.
#
#
# <h2 id='moduleObjectives'>Learning Objectives</h2>
#
# By the end of end of this module, a student should be able to:
# * <a href="#p1">Objective 1</a>: Tokenze text
# * <a href="#p1">Objective 2</a>: Remove stop words from text
# * <a href="#p3">Objective 3</a>: Perform stemming and lemmatization on tokens
#
# ## Conda Environments
#
# You will be completing each module this sprint on your machine. We will be using conda environments to manage the packages and their dependencies for this sprint's content. In a classroom setting, instructors typically abstract away environment for you. However, environment management is an important professional data science skill. We showed you how to manage environments using pipvirtual env during Unit 3, but in this sprint, we will introduce an environment management tool common in the data science community:
#
# > __conda__: Package, dependency and environment management for any language—Python, R, Ruby, Lua, Scala, Java, JavaScript, C/ C++, FORTRAN, and more.
#
# The easiest way to install conda on your machine is via the [Anaconda Distribution](https://www.anaconda.com/distribution/) of Python & R. Once you have conda installed, read ["A Guide to Conda Environments"](https://towardsdatascience.com/a-guide-to-conda-environments-bc6180fc533). This article will provide an introduce into some of the conda basics. If you need some additional help getting started, the official ["Setting started with conda"](https://conda.io/projects/conda/en/latest/user-guide/getting-started.html) guide will point you in the right direction.
#
# To get the sprint environment setup:
#
# 1. Open your command line tool (Terminal for MacOS, Anaconda Prompt for Windows)
# 2. Navigate to the folder with this sprint's content. There should be a `requirements.txt`
# 3. Run `conda env create -n U4-S1-NLP` => You can also rename the environment if you would like. Once the command completes, your conda environment should be ready.
# 4. Now, we are going to add in the require python packages for this sprint. You will need to 'activate' the conda environment: `source activate U4-S1-NLP` on Terminal or `conda activate U4-S1-NLP` on Anaconda Prompt. Once your environment is activate, run `pip install -r requirements.txt` which will install the required packages into your environment.
# 5. We are going to also add an Ipython Kernel reference to your conda environment, so we can use it from JupyterLab.
# 6. Next run `python -m ipykernel install --user --name U4-S1-NLP --display-name "U4-S1-NLP (Python3)"` => This will add a json object to an ipython file, so JupterLab will know that it can use this isolated instance of Python. :)
# 7. Last step, we need to install the models for Spacy. Run these commands `python -m spacy download en_core_web_md` and `python -m spacy download en_core_web_lg`
# 8. Deactivate your conda environment and launch JupyterLab. You should know see "U4-S1-NLP (Python3)" in the list of available kernels on launch screen.

# %% [markdown]
# # Tokenze Text (Learn)
# <a id="p1"></a>

# %% [markdown]
# ## Overview
#
# > **token**: an instance of a sequence of characters in some particular document that are grouped together as a useful semantic unit for processing
#
# > [_*Introduction to Information Retrival*_](https://nlp.stanford.edu/IR-book/)
#
#
# ### The attributes of good tokens
#
# * Should be stored in an iterable datastructure
#   - Allows analysis of the "semantic unit"
# * Should be all the same case
#   - Reduces the complexity of our data
# * Should be free of non-alphanumeric characters (ie punctuation, whitespace)
#   - Removes information that is probably not relevant to the analysis

# %% [markdown]
# Let's pretend we are trying analyze the random sequence here. Question: what is the most common character in this sequence?

# %%
random_seq = "AABAAFBBBBCGCDDEEEFCFFDFFAFFZFGGGGHEAFJAAZBBFCZ"

# %% [markdown]
# A useful unit of analysis for us is going to be a letter or character

# %%
tokens = list(random_seq)
print(tokens)
# Out:
# ['A', 'A', 'B', 'A', 'A', 'F', 'B', 'B', 'B', 'B', 'C', 'G', 'C', 'D', 'D', 'E', 'E', 'E', 'F', 'C', 'F', 'F', 'D', 'F', 'F', 'A', 'F', 'F', 'Z', 'F', 'G', 'G', 'G', 'G', 'H', 'E', 'A', 'F', 'J', 'A', 'A', 'Z', 'B', 'B', 'F', 'C', 'Z']

# %% [markdown]
# Our tokens are already "good": in an iterable datastructure, all the same case, and free of noise characters (punctionation, whitespace), so we can jump straight into analysis.

# %%
import seaborn as sns

sns.countplot(tokens);

# %% [markdown]
# The most common character in our sequence is  "F". We can't just glance at the the sequence to know which character is the most common. We (humans) struggle to subitize complex data (like random text sequences).
#
# > __Subitize__ is the ability to tell the number of objects in a set, quickly, without counting.
#
# We need to chunk the data into countable pieces "tokens" for us to analyze them. This inability subitize text data is the motivation for our discussion today.

# %% [markdown]
# ### Tokenizing with Pure Python

# %%
sample = "Friends, Romans, countrymen, lend me your ears;"

# %% [markdown]
# ##### Iterable Tokens
#
# A string object in Python is already iterable. However, the item you iterate over is a character not a token:
#
# ```
# from time import sleep
# for num, character in enumerate(sample):
#     sleep(.5)
#     print(f"Char {num} - {character}", end="\r")
# ```
#
# If we instead care about the words in our sample (our semantic unit), we can use the string method `.split()` to seperate the whitespace and create iterable units. :)

# %%
sample.split(" ")
# Out:
# ['Friends,', 'Romans,', 'countrymen,', 'lend', 'me', 'your', 'ears;']

# %% [markdown]
# ##### Case Normalization
# A common data cleaning data cleaning task with token is to standardize or normalize the case. Normalizing case reduces the chance that you have duplicate records for things which have practically the same semantic meaning. You can use either the `.lower()` or `.upper()` string methods to normalize case.
#
# Consider the following example:

# %%
# !ls 
import pandas as pd
df = pd.read_csv('Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products_May19.csv')
# Out:
#  data
#  Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products_May19.csv
#  images
#  LS_DS_411_Text_Data_Assignment.ipynb
# 'LS_DS_411_Text Data_Lecture.ipynb'
#  __MACOSX
#  previous_lectures
#  Untitled.ipynb

# %%
# Notice anything odd here? 
df['brand'].value_counts()
# Out:
# Amazon          16153
# Amazonbasics    12169
# AmazonBasics       10
# Name: brand, dtype: int64

# %%
# Much cleaner
df['brand'] = df['brand'].apply(lambda x: x.lower())
df['brand'].value_counts()
# Out:
# amazon          16153
# amazonbasics    12179
# Name: brand, dtype: int64

# %% [markdown]
# ##### Keep Only Alphanumeric Characters
# Yes, we only want letters and numbers. Everything else is probably noise: punctionation, whitespace, and other notation. This one is little bit more complicatd than our previous example. Here we will have to import the base package `re` (regular expressions).
#
# The only regex expression pattern you need for this is `'[^a-zA-Z ^0-9]'` which keeps lower case letters, upper case letters, spaces, and numbers.

# %%
sample = sample+" 911"
print(sample)
# Out:
# Friends, Romans, countrymen, lend me your ears; 911

# %%
import re

re.sub(r'[^a-zA-Z ^0-9]', '', sample)
# Out:
# 'Friends Romans countrymen lend me your ears 911'

# %% [markdown]
# #### Two Minute Challenge
# - Complete the function `tokenize` below
# - Combine the methods which we discussed above to clean text before we analyze it
# - You can put the methods in any order you want

# %%
def tokenize(text):
    """Parses a string into a list of semantic units (words)

    Args:
        text (str): The string that the function will tokenize.

    Returns:
        list: tokens parsed out by the mechanics of your choice
    """
    
    tokens = re.sub(r'[^a-zA-Z ^0-9]', '', text)
    tokens = tokens.lower().split()
    
    return tokens

# %%
tokenize(sample)

# %% [markdown]
# ## Follow Along
#
# Our inability to analyze text data becomes quickly amphilfied in business context. Consider the following:
#
# A business which sells widgets also collects customer reviews of those widgets. When the business first started out, they had a human read the reviews to look for patterns. Now, the business sells thousands of widgets a month. The human readers can't keep up with the pace of reviews to synthesize an accurate analysis. They need some science to help them analyze their data.
#
# Now, let's pretend that business is Amazon, and the widgets are Amazon products such as the Alexa, Echo, or other AmazonBasics products. Let's analyze their reviews with some counts. This dataset is available on [Kaggle](https://www.kaggle.com/datafiniti/consumer-reviews-of-amazon-products/).

# %%
"""
Import Statements
"""

# Base
from collections import Counter
import re
 
import pandas as pd

# Plotting
#!pip -q install squarify
import squarify
import matplotlib.pyplot as plt
import seaborn as sns

# NLP Libraries
#!pip -q install spacy
import spacy
from spacy.tokenizer import Tokenizer
from nltk.stem import PorterStemmer
#!python -m spacy download en
#!python -m spacy download en_core_web_lg
nlp = spacy.load("en_core_web_lg")
# Out:
# Requirement already satisfied: en_core_web_sm==2.2.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.0/en_core_web_sm-2.2.0.tar.gz#egg=en_core_web_sm==2.2.0 in /home/me/anaconda3/lib/python3.7/site-packages (2.2.0)
# Requirement already satisfied: spacy>=2.2.0 in /home/me/anaconda3/lib/python3.7/site-packages (from en_core_web_sm==2.2.0) (2.2.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/me/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.0->en_core_web_sm==2.2.0) (3.0.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/me/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.0->en_core_web_sm==2.2.0) (2.0.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.2.0 in /home/me/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.0->en_core_web_sm==2.2.0) (0.3.0)
# Requirement already satisfied: numpy>=1.15.0 in /home/me/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.0->en_core_web_sm==2.2.0) (1.17.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/me/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.0->en_core_web_sm==2.2.0) (2.22.0)
# Requirement already satisfied: srsly<1.1.0,>=0.1.0 in /home/me/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.0->en_core_web_sm==2.2.0) (0.1.0)
# Requirement already satisfied: thinc<7.2.0,>=7.1.1 in /home/me/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.0->en_core_web_sm==2.2.0) (7.1.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/me/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.0->en_core_web_sm==2.2.0) (1.0.2)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /home/me/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.0->en_core_web_sm==2.2.0) (0.4.1)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in /home/me/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.0->en_core_web_sm==2.2.0) (0.9.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/me/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en_core_web_sm==2.2.0) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/me/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en_core_web_sm==2.2.0) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/me/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en_core_web_sm==2.2.0) (1.25.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/me/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en_core_web_sm==2.2.0) (2019.9.11)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /home/me/anaconda3/lib/python3.7/site-packages (from thinc<7.2.0,>=7.1.1->spacy>=2.2.0->en_core_web_sm==2.2.0) (4.36.1)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /home/me/anaconda3/lib/python3.7/site-packages/en_core_web_sm -->
# /home/me/anaconda3/lib/python3.7/site-packages/spacy/data/en
# You can now load the model via spacy.load('en')
# Requirement already satisfied: en_core_web_lg==2.2.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.0/en_core_web_lg-2.2.0.tar.gz#egg=en_core_web_lg==2.2.0 in /home/me/anaconda3/lib/python3.7/site-packages (2.2.0)
# Requirement already satisfied: spacy>=2.2.0 in /home/me/anaconda3/lib/python3.7/site-packages (from en_core_web_lg==2.2.0) (2.2.1)
# Requirement already satisfied: srsly<1.1.0,>=0.1.0 in /home/me/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.0->en_core_web_lg==2.2.0) (0.1.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /home/me/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.0->en_core_web_lg==2.2.0) (0.4.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/me/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.0->en_core_web_lg==2.2.0) (2.0.2)
# Requirement already satisfied: numpy>=1.15.0 in /home/me/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.0->en_core_web_lg==2.2.0) (1.17.2)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in /home/me/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.0->en_core_web_lg==2.2.0) (0.9.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/me/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.0->en_core_web_lg==2.2.0) (1.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/me/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.0->en_core_web_lg==2.2.0) (2.22.0)
# Requirement already satisfied: thinc<7.2.0,>=7.1.1 in /home/me/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.0->en_core_web_lg==2.2.0) (7.1.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.2.0 in /home/me/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.0->en_core_web_lg==2.2.0) (0.3.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/me/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.0->en_core_web_lg==2.2.0) (3.0.2)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/me/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en_core_web_lg==2.2.0) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/me/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en_core_web_lg==2.2.0) (1.25.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/me/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en_core_web_lg==2.2.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/me/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en_core_web_lg==2.2.0) (2019.9.11)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /home/me/anaconda3/lib/python3.7/site-packages (from thinc<7.2.0,>=7.1.1->spacy>=2.2.0->en_core_web_lg==2.2.0) (4.36.1)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_lg')

# %%
# !ls
# Out:
#  data
#  Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products_May19.csv
#  images
#  LS_DS_411_Text_Data_Assignment.ipynb
# 'LS_DS_411_Text Data_Lecture.ipynb'
#  __MACOSX
#  previous_lectures
#  Untitled.ipynb

# %%
df = pd.read_csv('Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products_May19.csv')

# %%
df.head(2)
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 1  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
#
#                                                 name                  asins  \
# 0  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 1  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
#
#           brand                                         categories  \
# 0  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
# 1  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
#
#   primaryCategories                                          imageURLs  \
# 0   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
# 1   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
#
#                                                 keys  ... reviews.didPurchase  \
# 0  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...                 NaN
# 1  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...                 NaN
#
#   reviews.doRecommend reviews.id reviews.numHelpful reviews.rating  \
# 0                 NaN        NaN                NaN              3
# 1                 NaN        NaN                NaN              4
#
#                                   reviews.sourceURLs  \
# 0  https://www.amazon.com/product-reviews/B00QWO9...
# 1  https://www.amazon.com/product-reviews/B00QWO9...
#
#                                         reviews.text  \
# 0  I order 3 of them and one of the item is bad q...
# 1  Bulk is always the less expensive way to go fo...
#
#                                        reviews.title  reviews.username  \
# 0  ... 3 of them and one of the item is bad quali...        Byger yang
# 1  ... always the less expensive way to go for pr...              ByMG
#
#                                           sourceURLs
# 0  https://www.barcodable.com/upc/841710106442,ht...
# 1  https://www.barcodable.com/upc/841710106442,ht...
#
# [2 rows x 24 columns]

# %%
df.shape
# Out:
# (28332, 24)

# %%
# How can we count the raw text?
#df['reviews.text'].value_counts(normalize=True)[:50]
df['reviews.text'].value_counts()[:50]
# Out:
# good                60
# great               49
# Good                42
# Great               38
# ok                  33
# Great price         30
# great price         28
# Excellent           28
# Great value         27
# good price          23
# great value         22
# Great price!        18
# good value          17
# Great value.        16
# good deal           16
# Great deal          15
# Great product       15
# As expected         15
# Good deal           15
# OK                  15
# Good value          14
# Good batteries      14
# So far so good      13
# Good price          13
# great deal          13
# Great batteries.    13
# Great value!        13
# Work great          12
# Good buy            12
# very good           11
# Great deal!         11
# Great!              11
# excellent           11
# As described        11
# Great batteries     11
# Good value.         11
# as expected         11
# good batteries      11
# Great buy           11
# Great price.        11
# Nice                10
# great batteries     10
# Ok                  10
# Perfect!            10
# good product        10
# Work great.         10
# Very good            9
# Thanks               9
# love it              9
# Long lasting         9
# Name: reviews.text, dtype: int64

# %%
df.head()
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 1  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 2  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 3  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 4  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
#
#                                                 name                  asins  \
# 0  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 1  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 2  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 3  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 4  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
#
#           brand                                         categories  \
# 0  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
# 1  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
# 2  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
# 3  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
# 4  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
#
#   primaryCategories                                          imageURLs  \
# 0   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
# 1   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
# 2   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
# 3   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
# 4   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
#
#                                                 keys  ... reviews.doRecommend  \
# 0  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...                 NaN
# 1  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...                 NaN
# 2  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...                 NaN
# 3  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...                 NaN
# 4  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...                 NaN
#
#   reviews.id reviews.numHelpful reviews.rating  \
# 0        NaN                NaN              3
# 1        NaN                NaN              4
# 2        NaN                NaN              5
# 3        NaN                NaN              5
# 4        NaN                NaN              5
#
#                                   reviews.sourceURLs  \
# 0  https://www.amazon.com/product-reviews/B00QWO9...
# 1  https://www.amazon.com/product-reviews/B00QWO9...
# 2  https://www.amazon.com/product-reviews/B00QWO9...
# 3  https://www.amazon.com/product-reviews/B00QWO9...
# 4  https://www.amazon.com/product-reviews/B00QWO9...
#
#                                         reviews.text  \
# 0  I order 3 of them and one of the item is bad q...
# 1  Bulk is always the less expensive way to go fo...
# 2  Well they are not Duracell but for the price i...
# 3  Seem to work as well as name brand batteries a...
# 4  These batteries are very long lasting the pric...
#
#                                        reviews.title  reviews.username  \
# 0  ... 3 of them and one of the item is bad quali...        Byger yang
# 1  ... always the less expensive way to go for pr...              ByMG
# 2  ... are not Duracell but for the price i am ha...  BySharon Lambert
# 3  ... as well as name brand batteries at a much ...     Bymark sexson
# 4  ... batteries are very long lasting the price ...           Bylinda
#
#                                           sourceURLs tokens
# 0  https://www.barcodable.com/upc/841710106442,ht...   None
# 1  https://www.barcodable.com/upc/841710106442,ht...   None
# 2  https://www.barcodable.com/upc/841710106442,ht...   None
# 3  https://www.barcodable.com/upc/841710106442,ht...   None
# 4  https://www.barcodable.com/upc/841710106442,ht...   None
#
# [5 rows x 25 columns]

# %%
df['tokens'] = df['reviews.text'].apply(tokenize)

# %%
df['tokens'].head()
# Out:
# 0    [i, order, 3, of, them, and, one, of, the, ite...
# 1    [bulk, is, always, the, less, expensive, way, ...
# 2    [well, they, are, not, duracell, but, for, the...
# 3    [seem, to, work, as, well, as, name, brand, ba...
# 4    [these, batteries, are, very, long, lasting, t...
# Name: tokens, dtype: object

# %% [markdown]
# #### Analyzing Tokens

# %%
# Object from Base Python
from collections import Counter

# The object `Counter` takes an iterable, but you can instaniate an empty one and update it. 
word_counts = Counter()

# Update it based on a split of each of our documents
df['tokens'].apply(lambda x: word_counts.update(x))

# Print out the 10 most common words
word_counts.most_common(10)
# Out:
# [('the', 28836),
#  ('and', 22302),
#  ('i', 20588),
#  ('to', 19537),
#  ('for', 17918),
#  ('a', 17599),
#  ('it', 16793),
#  ('is', 11482),
#  ('my', 11149),
#  ('this', 10420)]

# %% [markdown]
# Let's create a fuction which takes a corpus of document and returns and dataframe of word counts for us to analyze.

# %%
def count(docs):
        "Dataframe of wordcount information for "
        word_counts = Counter()
        appears_in = Counter()
        
        total_docs = len(docs)

        for doc in docs:
            word_counts.update(doc)
            appears_in.update(set(doc))

        temp = zip(word_counts.keys(), word_counts.values())
        
        wc = pd.DataFrame(temp, columns = ['word', 'count'])

        wc['rank'] = wc['count'].rank(method='first', ascending=False)
        total = wc['count'].sum()

        wc['pct_total'] = wc['count'].apply(lambda x: x / total)
        
        wc = wc.sort_values(by='rank')
        wc['cul_pct_total'] = wc['pct_total'].cumsum()

        t2 = zip(appears_in.keys(), appears_in.values())
        ac = pd.DataFrame(t2, columns=['word', 'appears_in'])
        wc = ac.merge(wc, on='word')

        wc['appears_in_pct'] = wc['appears_in'].apply(lambda x: x / total_docs)
        
        return wc.sort_values(by='rank')

# %%
# Use the Function
wc = count(df['tokens'])

# %%
appears_in = Counter() 
for x in df['tokens'].apply(set):
    appears_in.update(x)
    #print(x)
appears_in
# Out:
# Counter({'missing': 29,
#          'aluminum': 4,
#          'spring': 8,
#          'item': 299,
#          'quality.': 220,
#          'battery': 1578,
#          'backup': 15,
#          'bad': 217,
#          'work.': 226,
#          'pcs': 1,
#          '3': 579,
#          'order': 278,
#          'expensive': 403,
#          'products': 198,
#          'way': 529,
#          'bulk': 132,
#          'like': 2127,
#          'price': 2672,
#          'duracell': 416,
#          'happy.': 50,
#          'work': 1914,
#          'brand': 957,
#          'better': 1101,
#          'great.': 651,
#          'long': 2085,
#          'lasting': 257,
#          'good.': 416,
#          'brand.': 153,
#          'again.': 397,
#          'difference': 206,
#          'arrive': 16,
#          'noticed': 112,
#          'house': 145,
#          'buy': 1783,
#          'christmas': 621,
#          'bought': 2916,
#          'purchase': 536,
#          'amazonbasics': 219,
#          'cell': 53,
#          'lot': 793,
#          "haven't": 338,
#          'basic': 292,
#          'hand.': 66,
#          'easier': 262,
#          'past': 76,
#          'problame': 2,
#          'ordered': 176,
#          'pleased.': 48,
#          'ive': 34,
#          'perfect.': 91,
#          'looking': 404,
#          'say.': 45,
#          'cheap': 417,
#          'non-rechargeable': 6,
#          'high': 229,
#          'duracell,': 51,
#          'juice': 21,
#          'price.': 1435,
#          'hold': 282,
#          'power': 256,
#          'energizer': 218,
#          'half': 181,
#          'aa': 386,
#          'good': 4633,
#          'shelf': 74,
#          'life.': 213,
#          'aaa': 264,
#          "i'll": 208,
#          'appear': 68,
#          "can't": 843,
#          'start': 120,
#          'buying': 480,
#          'sooner!': 3,
#          'great': 7187,
#          'basics': 227,
#          'superior': 22,
#          'too.': 247,
#          'ones.': 70,
#          'equal': 21,
#          'find': 393,
#          'large': 152,
#          'believe': 123,
#          'packages': 33,
#          "didn't": 407,
#          'liked': 151,
#          'beat.': 48,
#          'feel': 193,
#          'tests,': 5,
#          'others).': 1,
#          'hard': 247,
#          'mixed-bag': 1,
#          'had,': 3,
#          'purchases,': 2,
#          'maybe': 145,
#          'recent': 21,
#          'started': 135,
#          'however,': 165,
#          'getting': 398,
#          'longer.': 51,
#          'brands': 391,
#          'them.': 482,
#          '(inconsistent': 1,
#          'there.': 76,
#          'works': 1427,
#          'night': 108,
#          'guests': 2,
#          'love': 3154,
#          "tank's": 1,
#          'switch': 72,
#          'easily': 200,
#          'use': 2881,
#          'fish': 4,
#          'light': 492,
#          'want': 478,
#          'great,': 218,
#          'days': 208,
#          'keyboards': 11,
#          'got': 1182,
#          'comment': 21,
#          'delivery': 52,
#          'quick': 132,
#          'em': 6,
#          'year': 1444,
#          'price,': 424,
#          'job,': 10,
#          'things': 424,
#          'need': 792,
#          'arrived': 158,
#          'exactly': 176,
#          'perfect': 922,
#          'shipping.': 40,
#          'thankful': 5,
#          'condition': 7,
#          'needed': 343,
#          'to.': 101,
#          'able': 531,
#          'know': 372,
#          "don't": 1192,
#          'candles': 59,
#          'trail': 22,
#          'cameras.': 10,
#          'cold': 19,
#          '(which': 54,
#          'size': 696,
#          'exposed': 15,
#          'purchased': 1185,
#          'lacking.': 3,
#          'towels.': 1,
#          'batteries.': 1427,
#          'opinion': 36,
#          'life,': 70,
#          'sheets': 1,
#          'crazy)': 1,
#          'north': 6,
#          'cameras': 38,
#          'near': 42,
#          'led': 99,
#          'beeding': 1,
#          'temps': 2,
#          'house.': 83,
#          'duracel': 17,
#          'package': 126,
#          'considering': 60,
#          'cheaper.': 68,
#          'control': 230,
#          'lasted': 266,
#          'toys': 212,
#          '(december)': 1,
#          'replacement': 165,
#          'month': 158,
#          'tv': 202,
#          'working': 299,
#          'doorbell': 1,
#          'long...': 2,
#          '2months': 1,
#          'needs': 243,
#          'gifts': 53,
#          'remote': 225,
#          '.': 285,
#          'door.': 13,
#          'second': 246,
#          'ship': 24,
#          'on!': 22,
#          'exploded': 7,
#          'xbox': 152,
#          'reviews': 161,
#          'controllers': 69,
#          'said.': 14,
#          'disappointed!': 9,
#          'names': 21,
#          'happy': 712,
#          '4star': 2,
#          'definitely': 471,
#          'hand': 145,
#          '48': 80,
#          'box': 293,
#          'you!': 37,
#          'pretty': 496,
#          'job': 170,
#          'strong': 89,
#          'priceim': 2,
#          'weak': 29,
#          'satisfied.thank': 2,
#          'gave': 195,
#          'batteries,': 485,
#          'recommend': 942,
#          'these.': 172,
#          "we've": 73,
#          'product.': 471,
#          'cause': 30,
#          'times': 276,
#          'remain': 2,
#          'reasonable': 121,
#          'out.': 145,
#          'meaning': 9,
#          'chance': 39,
#          'hopefully': 27,
#          'time': 1219,
#          'years': 391,
#          'company': 19,
#          'knowing': 42,
#          'thought': 271,
#          'thanks..': 1,
#          'fit': 125,
#          'fault': 10,
#          'ok,it': 1,
#          'this.': 197,
#          'nice': 1008,
#          'game': 174,
#          'weeks.': 45,
#          'ago.': 50,
#          'pricing': 17,
#          'longer': 373,
#          'stores.': 34,
#          'convenient': 127,
#          'compare': 91,
#          "let's": 17,
#          'share': 33,
#          'kids': 1657,
#          'having': 463,
#          'kids.': 366,
#          'grand': 147,
#          'far': 795,
#          'okay': 33,
#          'long.': 181,
#          'sons': 42,
#          'time.': 480,
#          'powers': 7,
#          'months': 221,
#          'eeeks': 1,
#          'wont': 45,
#          'kno': 1,
#          'energizer-': 1,
#          'found': 322,
#          'capacity.': 21,
#          "that's": 235,
#          'horrible.': 16,
#          'brand-name': 6,
#          'try': 173,
#          'available': 215,
#          'week.': 67,
#          'usage,': 5,
#          'subscription': 65,
#          'depend': 9,
#          'switched': 32,
#          'usage.': 34,
#          'wireless': 155,
#          'microphone': 13,
#          '1/4': 15,
#          'that,': 69,
#          'preferred': 21,
#          'amazon,': 87,
#          'expiration': 27,
#          '2027.': 1,
#          '3rd': 62,
#          "i've": 640,
#          'ones': 291,
#          'satisfied': 145,
#          '100': 49,
#          '10': 182,
#          'experimented': 1,
#          '2.': 28,
#          'is,': 40,
#          'consistent': 12,
#          '12': 72,
#          'window': 18,
#          '2': 809,
#          '-': 490,
#          '17': 13,
#          '12.': 4,
#          'average': 55,
#          'hours': 248,
#          'charge': 345,
#          'around,': 9,
#          'worked': 311,
#          '4-6': 2,
#          'run': 275,
#          'brands.': 368,
#          'junk': 27,
#          'clock.': 12,
#          'digital': 59,
#          'best.': 64,
#          'weeks': 129,
#          'simple': 238,
#          'year.': 72,
#          '4': 563,
#          '6': 242,
#          'ago': 92,
#          'back.': 38,
#          'brands,': 85,
#          'looked': 80,
#          'cost.': 92,
#          'yeah,': 3,
#          'date': 55,
#          'inedible.': 1,
#          '1992.': 1,
#          'im': 29,
#          'faster': 198,
#          'ordering': 92,
#          '!!': 31,
#          'usedd': 1,
#          'pack,': 21,
#          'would!!,so': 1,
#          'me.': 228,
#          'packs': 79,
#          'new': 845,
#          'device': 534,
#          'rechargeable': 93,
#          'recharging': 13,
#          '8': 437,
#          'worth': 453,
#          'fooling': 2,
#          'day': 265,
#          'day.': 116,
#          'anywhere.': 39,
#          'simplicity': 5,
#          'hour': 59,
#          'lowest': 18,
#          'putting': 50,
#          'while..': 1,
#          'quantity..': 1,
#          'tthrough': 1,
#          'fast.': 121,
#          'kind.': 5,
#          'others.': 66,
#          'standard': 68,
#          'everyday.': 31,
#          'excellent': 631,
#          'performance': 256,
#          'expected.': 161,
#          'earlier': 38,
#          'affordable,': 15,
#          'product!': 96,
#          "they're": 285,
#          'batteries!': 231,
#          'thank': 162,
#          'product': 1232,
#          'money!': 32,
#          'amazon!': 53,
#          'saves': 18,
#          'cost': 269,
#          'purchase!': 45,
#          'rock!': 2,
#          'nothing.': 12,
#          'opinion,': 14,
#          'far.': 220,
#          'amazing': 230,
#          'end': 117,
#          'affordable': 146,
#          'update': 119,
#          'walmart.': 3,
#          "aaa's": 15,
#          'jn': 1,
#          'issues.': 86,
#          'report': 6,
#          'plan': 73,
#          'seller.': 8,
#          'you.': 96,
#          'fine': 285,
#          'currently': 44,
#          'case.': 103,
#          'capacity).': 2,
#          'internal': 31,
#          'took': 186,
#          'maxell,': 3,
#          "'good'": 2,
#          'away': 102,
#          'quest': 7,
#          'if/when': 3,
#          'low': 296,
#          'tied': 12,
#          'version': 189,
#          'usage': 61,
#          'equipment,': 4,
#          'comparative': 3,
#          'alkaline': 177,
#          '--': 40,
#          'summarizing': 2,
#          'profile).': 2,
#          'ran': 49,
#          'equipment': 22,
#          '(48': 2,
#          'mah': 5,
#          'rate': 40,
#          '7': 271,
#          'reviewed': 18,
#          "couldn't": 169,
#          'capacity': 25,
#          'was:disch': 2,
#          'capacity-wise,': 2,
#          'findings': 2,
#          '(or': 32,
#          '1005': 2,
#          '400': 4,
#          '50': 33,
#          'trust': 45,
#          'eclipsed': 2,
#          'medium': 14,
#          'coppertop': 7,
#          "'all": 2,
#          'test': 75,
#          'comperable': 2,
#          "you'd": 41,
#          'conditions)': 2,
#          'hrsas': 2,
#          'party,': 2,
#          'results:disch': 2,
#          'value-wise': 2,
#          'mah)': 2,
#          'see,': 6,
#          '670': 2,
#          'mouse,': 24,
#          'rates': 3,
#          '(discharge': 2,
#          'pack)': 3,
#          'terms': 29,
#          'dollar': 89,
#          'you,': 25,
#          "aaa's.": 5,
#          'think': 400,
#          'runtime100': 2,
#          'browse': 37,
#          'search': 59,
#          '/': 22,
#          'data': 31,
#          '590': 2,
#          'super': 245,
#          'best': 1171,
#          'comparison': 31,
#          'graph': 2,
#          'higher': 99,
#          'pc2400bkd09energizer': 2,
#          'closable': 2,
#          'top-selling': 2,
#          'tests/reviews:i': 2,
#          "'mah'": 2,
#          'future,': 4,
#          'acdelco': 3,
#          '0.31/ea': 2,
#          'plastic': 95,
#          'case100': 2,
#          'test,': 4,
#          'tested,': 7,
#          'tests/reviews': 2,
#          'flashlight200': 2,
#          'results': 19,
#          'category': 3,
#          'hrs200': 2,
#          'were:disch': 2,
#          'attached': 15,
#          'rt': 2,
#          'low-power': 3,
#          'pack),': 2,
#          '0.21/ea': 2,
#          '1.5': 22,
#          'application': 22,
#          'means': 46,
#          'table': 73,
#          'bt-c2000': 2,
#          'flashlight400': 2,
#          'way.': 38,
#          'repeatable,': 2,
#          'clearly': 15,
#          'drawer': 17,
#          'bright': 98,
#          'procell,': 2,
#          'box.': 105,
#          'posted': 7,
#          'hrs': 16,
#          "i'd": 138,
#          'rayovac.': 7,
#          'keyboard,': 23,
#          'poorly': 8,
#          'conditions,': 2,
#          'rayovacs': 13,
#          'toy': 57,
#          'energy/dollar': 2,
#          'beatable': 2,
#          '2.9': 2,
#          'certainly': 37,
#          'contract': 2,
#          'coppertop,': 3,
#          '623': 2,
#          'push': 24,
#          '1.1': 2,
#          'reduces': 5,
#          'place,': 7,
#          'noting': 2,
#          'respectable': 5,
#          "aa's": 26,
#          'performed': 30,
#          'cardboard': 72,
#          'discharge': 18,
#          'spot': 21,
#          'drawer.': 9,
#          'value': 647,
#          'method': 10,
#          'now),': 2,
#          '908': 2,
#          'ma': 2,
#          'environmental': 2,
#          'organization': 3,
#          'options.comparison:these': 2,
#          'rates.the': 2,
#          'hrsmy': 2,
#          '(i': 42,
#          'mentions': 2,
#          'cheapest': 24,
#          '4.5': 6,
#          'short,': 9,
#          'cellrayovac': 2,
#          '(and': 48,
#          'specifically': 31,
#          'dollar.': 3,
#          '(36': 3,
#          'popular': 40,
#          '200': 5,
#          'alkalines)': 2,
#          'achieve': 9,
#          '4.3': 2,
#          '1.7': 2,
#          'usable': 6,
#          'somewhat': 19,
#          'scenarios,': 3,
#          'electronic': 65,
#          'blister': 7,
#          'packduracell': 2,
#          'supplied': 2,
#          'edge': 10,
#          'additional': 66,
#          '36': 17,
#          'bit': 276,
#          'compared': 250,
#          'rayovac': 30,
#          'fully': 95,
#          'cheaper': 339,
#          'ma,': 2,
#          'purposes,': 6,
#          'look': 236,
#          'possible': 17,
#          'pack': 223,
#          'procell': 14,
#          'dividing': 3,
#          'motorized': 5,
#          'flashlightnote': 2,
#          'batteriesmaxell': 2,
#          'premium.finally,': 2,
#          'slots': 8,
#          "reviews'": 2,
#          'tested': 85,
#          'garbage': 7,
#          'come': 350,
#          'affects': 2,
#          'data.': 10,
#          'decent': 253,
#          'source': 21,
#          'in-dept': 2,
#          'trusted': 13,
#          'website': 12,
#          'max,': 3,
#          'precise': 2,
#          'likely': 34,
#          '443': 2,
#          'mah.': 2,
#          '(0.31/ea': 2,
#          'gathered': 3,
#          'horrible': 16,
#          '9': 127,
#          'equipment.': 11,
#          'good,': 182,
#          'batteriesduracell': 2,
#          'mn2400': 2,
#          'leader.': 2,
#          'runtime': 4,
#          'exact': 13,
#          'significantly': 22,
#          '20': 58,
#          'size,': 70,
#          'despite': 34,
#          'resistance': 6,
#          'test.': 5,
#          'sitting': 38,
#          'purposes.': 19,
#          'advantage': 31,
#          '864': 2,
#          'control,': 10,
#          'list.acdelco': 2,
#          '914': 2,
#          "review.i've": 2,
#          'trouble': 51,
#          'review': 108,
#          'spent': 58,
#          'different': 297,
#          '...': 44,
#          'analyzer': 2,
#          'max': 6,
#          '(maybe': 9,
#          'gigantic': 4,
#          'pages': 48,
#          'provide': 49,
#          'computed': 2,
#          "aaa's,": 3,
#          'acdelco,': 3,
#          'opus': 2,
#          'linked': 25,
#          'hrs400': 2,
#          'winner': 9,
#          'packaging': 150,
#          'images': 16,
#          '(same': 2,
#          'sample': 4,
#          '997': 2,
#          'blown': 9,
#          'amazon).': 4,
#          'current': 33,
#          'but,': 63,
#          'types': 20,
#          'all-around': 7,
#          'right': 390,
#          'typical': 40,
#          '1200': 3,
#          'etc': 54,
#          'important': 41,
#          '(stored': 1,
#          'life': 648,
#          'storage': 222,
#          'indoors).': 1,
#          'uses': 341,
#          'bang': 56,
#          'buck!!': 1,
#          'touch': 139,
#          'sure': 362,
#          'first.': 18,
#          'batch': 39,
#          'toy,': 8,
#          'blew': 5,
#          'remotes': 128,
#          'dud': 5,
#          "aren't": 78,
#          'store': 586,
#          'change': 172,
#          'counting': 8,
#          '1': 192,
#          'often.': 44,
#          'child': 288,
#          'play': 965,
#          'magic': 7,
#          'month.': 38,
#          'gotten': 62,
#          'going': 379,
#          'nearly': 74,
#          'years.': 75,
#          'example': 15,
#          "i'm": 819,
#          'powered': 53,
#          'popped': 15,
#          'battery!': 14,
#          'oprah.': 1,
#          'fantastic': 100,
#          'stockpile.': 1,
#          'battery!...': 1,
#          'drink,': 1,
#          'integral': 1,
#          'probably': 178,
#          'chuckle': 1,
#          "'primitive'": 1,
#          'price/quality': 1,
#          'combination.': 1,
#          'yet.': 113,
#          'beat': 395,
#          'lives.': 1,
#          'daily': 98,
#          'food,': 1,
#          'shelter,': 1,
#          'love,': 15,
#          'enginzer': 2,
#          'stock': 84,
#          'purchaser': 2,
#          'repeat': 8,
#          'graphics': 67,
#          'lasts': 190,
#          'exciting': 5,
#          'though,': 39,
#          'at.': 20,
#          'consider': 35,
#          'duracell.': 84,
#          'improving': 1,
#          'sizes.': 13,
#          'home.': 64,
#          'deal.': 167,
#          'awesome': 368,
#          'cars': 18,
#          'him.': 59,
#          'placed.': 4,
#          'testing': 23,
#          'up!': 21,
#          'costco': 55,
#          'thumbs': 14,
#          'replace': 335,
#          'based': 73,
#          'kirkland,': 3,
#          'nicely': 63,
#          'past.': 22,
#          'experience': 114,
#          'clear': 184,
#          'kirkland': 29,
#          'transmitters': 2,
#          'sorry': 20,
#          'disappointed': 132,
#          'rc': 10,
#          'use.': 881,
#          'quickly': 163,
#          'smaller': 154,
#          'runs': 94,
#          'realize': 27,
#          'times.': 55,
#          'online': 180,
#          'bulk.': 18,
#          'xpected.': 1,
#          'thes': 1,
#          'gaming.': 13,
#          'well.': 576,
#          'headset.': 2,
#          'useful': 86,
#          'frequent': 14,
#          'alternative': 81,
#          'gaming': 64,
#          'controller': 47,
#          'particularly': 19,
#          'preform': 3,
#          'deal': 533,
#          'rechargeable.': 10,
#          'staying': 6,
#          'mainly': 108,
#          'controllers.': 38,
#          'highly': 343,
#          'all.': 158,
#          'running': 115,
#          'amazon.': 183,
#          'swears': 1,
#          'agree': 3,
#          'money': 377,
#          'worried': 27,
#          'advised': 1,
#          'friend': 65,
#          'family': 187,
#          'commodity': 7,
#          'do,': 28,
#          'value.': 260,
#          'supposed': 66,
#          'store.': 208,
#          'price!': 355,
#          'money.': 242,
#          'little': 899,
#          'everyday': 82,
#          'approximately': 17,
#          'pack.': 48,
#          'forth': 13,
#          'therefore,': 12,
#          'tired': 39,
#          'bargain.': 28,
#          'local': 83,
#          'small': 403,
#          'decided': 249,
#          'bank': 6,
#          'inexpensive': 166,
#          'account!': 1,
#          'them,': 93,
#          "you're": 148,
#          'deal,': 72,
#          'low.': 30,
#          '9-volt.': 2,
#          'comes': 313,
#          'shopper,': 3,
#          'pleased': 228,
#          'aa,': 15,
#          'tried': 216,
#          'aaa,': 16,
#          'comparable': 102,
#          'held': 74,
#          'remotes,': 68,
#          'leappads,': 1,
#          'lot.': 60,
#          'household': 40,
#          'lifespan': 14,
#          'here.': 42,
#          'defintely': 2,
#          'plenty': 171,
#          'recommended': 80,
#          'pick': 64,
#          'friends': 69,
#          'especially': 264,
#          'sets': 38,
#          'birthdays': 10,
#          "those.i've": 1,
#          'happily': 7,
#          'handy': 102,
#          'quality/lifespan.': 1,
#          'face': 28,
#          'practically': 9,
#          'holidays!': 4,
#          'hit': 68,
#          'family,': 3,
#          'couple': 191,
#          'crazy': 41,
#          'ps3': 1,
#          'thanks': 166,
#          'controls': 242,
#          'television': 17,
#          'cute': 14,
#          'lol)!': 1,
#          'money,': 54,
#          'recommend!': 35,
#          'matters,': 1,
#          '(if': 10,
#          'figured': 64,
#          'long-lasting,': 4,
#          'stores!i': 1,
#          'teacher,': 1,
#          'excessive': 1,
#          'refused': 9,
#          'amounts': 10,
#          'spend': 155,
#          'option!': 1,
#          'tons': 88,
#          "won't": 236,
#          'turned': 81,
#          'clean': 19,
#          'while.': 45,
#          'selling': 36,
#          'candle': 19,
#          'week': 137,
#          'infrequently': 2,
#          'old,': 67,
#          'didnt': 34,
#          'brown': 14,
#          'ruined': 15,
#          'happen': 28,
#          'leaked.': 3,
#          'continue': 111,
#          'real': 128,
#          'candle,': 2,
#          'check': 144,
#          'conditioned': 3,
#          'batch,': 6,
#          'heads': 3,
#          'air': 25,
#          'before.': 32,
#          'disappointed...': 3,
#          'indoor': 9,
#          'flameless': 14,
#          'dont': 93,
#          'then,': 13,
#          'long...a': 1,
#          'saying': 41,
#          'worry': 120,
#          'good!': 56,
#          'lieutenant': 1,
#          'thing.': 41,
#          'thats': 22,
#          'dan': 2,
#          'said,': 41,
#          'more.': 169,
#          '-forrest': 1,
#          'him,': 11,
#          'far,': 159,
#          'room.': 18,
#          'living': 29,
#          'bunch.': 7,
#          'guy': 27,
#          'times!': 3,
#          'toys,': 70,
#          'buy.': 190,
#          'time,': 118,
#          'to,': 19,
#          'purchase.': 273,
#          'instead': 149,
#          'outdoor': 17,
#          'namebrands,': 1,
#          'pair': 48,
#          'surveillance': 3,
#          'leading': 37,
#          'flashlights': 55,
#          'measures': 3,
#          '10-year,': 1,
#          'fluctuate)': 1,
#          'claimed': 3,
#          'that.i': 1,
#          'locally.': 4,
#          'far)': 3,
#          'stumbled': 7,
#          "there's": 75,
#          'glad': 206,
#          'bothered': 8,
#          'checking': 48,
#          'waste': 77,
#          "reviewer's": 1,
#          'tens': 2,
#          'sealed': 16,
#          'no-leak': 1,
#          '(so': 7,
#          'performance.': 76,
#          '1/4.': 1,
#          'paying': 37,
#          'packaging.so': 1,
#          'x': 8,
#          'all,': 44,
#          'she,': 1,
#          'remember)': 1,
#          'deals': 25,
#          'each,': 3,
#          'profile': 51,
#          'claims': 10,
#          'advice': 3,
#          'fellow': 3,
#          'tiny': 15,
#          'packaging.': 62,
#          'machines.': 1,
#          'throw': 38,
#          'bring': 32,
#          'controls.': 76,
#          'details.': 4,
#          'big': 461,
#          'electronics': 75,
#          'pictures': 83,
#          'chain': 2,
#          'scavenging': 1,
#          'packaged': 120,
#          'days.': 62,
#          'stealing': 1,
#          'wrapped': 69,
#          'renewed': 1,
#          'vigor.': 1,
#          'included': 81,
#          'hate': 46,
#          'devices': 182,
#          'bunch': 49,
#          'branded': 40,
#          'extra': 209,
#          'future.': 52,
#          'afford': 20,
#          'nicely,': 1,
#          'mail': 10,
#          'course': 41,
#          'bunny': 25,
#          'cant': 98,
#          'it!': 531,
#          'in.': 91,
#          '4,': 16,
#          'get,': 9,
#          'individual': 17,
#          'white': 74,
#          'inside': 57,
#          'packed': 39,
#          'reusable': 3,
#          'leaking': 42,
#          'wrapping': 14,
#          'off.': 48,
#          'coming': 44,
#          'barely': 35,
#          'terrible!': 3,
#          'multiple': 99,
#          'shoot': 11,
#          'camera': 237,
#          'mower.': 1,
#          'convenient.': 31,
#          'trying': 137,
#          'needed.': 97,
#          'bargain': 56,
#          'perfectly': 100,
#          'gas': 7,
#          'packaged.': 23,
#          'offer': 49,
#          'genuine': 2,
#          'transfers': 1,
#          'bundled': 8,
#          'pump': 9,
#          'riding': 7,
#          'mower': 2,
#          'fueling': 1,
#          ...})

# %%
wc.head()
# Out:
#    word  appears_in  count  rank  pct_total  cul_pct_total  appears_in_pct
# 16  the       13185  28836   1.0   0.039350       0.039350        0.465375
# 3   and       13731  22302   2.0   0.030434       0.069784        0.484646
# 4     i       10301  20588   3.0   0.028095       0.097879        0.363582
# 10   to       11312  19537   4.0   0.026661       0.124539        0.399266
# 32  for       12101  17918   5.0   0.024451       0.148990        0.427114

# %%
import seaborn as sns

# Cumulative Distribution Plot
sns.lineplot(x='rank', y='cul_pct_total', data=wc);

# %%
wc[wc['rank'] <= 20]['cul_pct_total'].max()
# Out:
# 0.3353465992363599

# %%
wc[wc['rank'] <= 20]['cul_pct_total'].max()
# Out:
# 0.3353465992363599

# %%
import squarify
import matplotlib.pyplot as plt

wc_top20 = wc[wc['rank'] <= 20]

squarify.plot(sizes=wc_top20['pct_total'], label=wc_top20['word'], alpha=.8 )
plt.axis('off')
plt.show()

# %% [markdown]
# ### Processing Raw Text with Spacy
#
# Spacy's datamodel for documents is unique among NLP libraries. Instead of storing the documents components repeatively in various datastructures, Spacy indexes components and simply stores the lookup informaiton.
#
# This is often why Spacy is considered to be more production grade than library like NLTK.

# %%
import spacy
from spacy.tokenizer import Tokenizer

nlp = spacy.load("en_core_web_lg")

# Tokenizer
tokenizer = Tokenizer(nlp.vocab)

# %%
# Print out list of tokens
[token.text for token in tokenizer(sample)]
# Out:
# ['Friends,', 'Romans,', 'countrymen,', 'lend', 'me', 'your', 'ears;', '911']

# %%
# Tokenizer Pipe

tokens = []

""" Make them tokens """
for doc in tokenizer.pipe(df['reviews.text'], batch_size=500):
    doc_tokens = [token.text for token in doc]
    tokens.append(doc_tokens)

df['tokens'] = tokens

# %%
df['tokens'].head()
# Out:
# 0    [I, order, 3, of, them, and, one, of, the, ite...
# 1    [Bulk, is, always, the, less, expensive, way, ...
# 2    [Well, they, are, not, Duracell, but, for, the...
# 3    [Seem, to, work, as, well, as, name, brand, ba...
# 4    [These, batteries, are, very, long, lasting, t...
# Name: tokens, dtype: object

# %%
wc = count(df['tokens'])

# %%
wc.head()
# Out:
#    word  appears_in  count  rank  pct_total  cul_pct_total  appears_in_pct
# 16  the       12316  25154   1.0   0.034219       0.034219        0.434703
# 22  and       13541  21850   2.0   0.029725       0.063944        0.477940
# 19    I        9913  19762   3.0   0.026884       0.090828        0.349887
# 5    to       11227  19324   4.0   0.026288       0.117117        0.396266
# 30  for       11790  17197   5.0   0.023395       0.140512        0.416137

# %%
wc_top20 = wc[wc['rank'] <= 20]

squarify.plot(sizes=wc_top20['pct_total'], label=wc_top20['word'], alpha=.8 )
plt.axis('off')
plt.show()

# %% [markdown]
# ## Challenge
#
# In the module project, you will apply tokenization to another set of review data and produce visualizations of those tokens.

# %% [markdown]
# # Stop Words (Learn)
# <a id="p2"></a>

# %% [markdown]
# ## Overview
# Section Agenda
# - What are they?
# - How do we get rid of them using Spacy?
# - Visualization
# - Libraries of Stop Words
# - Extending Stop Words
# - Statistical trimming
#
# If the visualizations above, you began to notice a pattern. Most of the words don't really add much to our undertanding of product reviews. Words such as "I", "and", "of", etc. have almost no semantic meaning to us. We call these useless words "stop words," because we should 'stop' ourselves from including them in the analysis.
#
# Most NLP libraries have built in lists of stop words that common english words: conjunctions, articles, adverbs, pronouns, and common verbs. The best practice, however, is to extend/customize these standard english stopwords for your problem's domain. If I am studying political science, I may want to exclude the word "politics" from my analysis; it's so common it does not add to my understanding.

# %% [markdown]
# ## Follow Along
#
# ### Default Stop Words
# Let's take a look at the standard stop words that came with our spacy model:

# %%
# Spacy's Default Stop Words
nlp.Defaults.stop_words
# Out:
# {"'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'could',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
#  'enough',
#  'even',
#  'ever',
#  'every',
#  'everyone',
#  'everything',
#  'everywhere',
#  'except',
#  'few',
#  'fifteen',
#  'fifty',
#  'first',
#  'five',
#  'for',
#  'former',
#  'formerly',
#  'forty',
#  'four',
#  'from',
#  'front',
#  'full',
#  'further',
#  'get',
#  'give',
#  'go',
#  'had',
#  'has',
#  'have',
#  'he',
#  'hence',
#  'her',
#  'here',
#  'hereafter',
#  'hereby',
#  'herein',
#  'hereupon',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'however',
#  'hundred',
#  'i',
#  'if',
#  'in',
#  'indeed',
#  'into',
#  'is',
#  'it',
#  'its',
#  'itself',
#  'just',
#  'keep',
#  'last',
#  'latter',
#  'latterly',
#  'least',
#  'less',
#  'made',
#  'make',
#  'many',
#  'may',
#  'me',
#  'meanwhile',
#  'might',
#  'mine',
#  'more',
#  'moreover',
#  'most',
#  'mostly',
#  'move',
#  'much',
#  'must',
#  'my',
#  'myself',
#  "n't",
#  'name',
#  'namely',
#  'neither',
#  'never',
#  'nevertheless',
#  'next',
#  'nine',
#  'no',
#  'nobody',
#  'none',
#  'noone',
#  'nor',
#  'not',
#  'nothing',
#  'now',
#  'nowhere',
#  'n‘t',
#  'n’t',
#  'of',
#  'off',
#  'often',
#  'on',
#  'once',
#  'one',
#  'only',
#  'onto',
#  'or',
#  'other',
#  'others',
#  'otherwise',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'part',
#  'per',
#  'perhaps',
#  'please',
#  'put',
#  'quite',
#  'rather',
#  're',
#  'really',
#  'regarding',
#  'same',
#  'say',
#  'see',
#  'seem',
#  'seemed',
#  'seeming',
#  'seems',
#  'serious',
#  'several',
#  'she',
#  'should',
#  'show',
#  'side',
#  'since',
#  'six',
#  'sixty',
#  'so',
#  'some',
#  'somehow',
#  'someone',
#  'something',
#  'sometime',
#  'sometimes',
#  'somewhere',
#  'still',
#  'such',
#  'take',
#  'ten',
#  'than',
#  'that',
#  'the',
#  'their',
#  'them',
#  'themselves',
#  'then',
#  'thence',
#  'there',
#  'thereafter',
#  'thereby',
#  'therefore',
#  'therein',
#  'thereupon',
#  'these',
#  'they',
#  'third',
#  'this',
#  'those',
#  'though',
#  'three',
#  'through',
#  'throughout',
#  'thru',
#  'thus',
#  'to',
#  'together',
#  'too',
#  'top',
#  'toward',
#  'towards',
#  'twelve',
#  'twenty',
#  'two',
#  'under',
#  'unless',
#  'until',
#  'up',
#  'upon',
#  'us',
#  'used',
#  'using',
#  'various',
#  'very',
#  'via',
#  'was',
#  'we',
#  'well',
#  'were',
#  'what',
#  'whatever',
#  'when',
#  'whence',
#  'whenever',
#  'where',
#  'whereafter',
#  'whereas',
#  'whereby',
#  'wherein',
#  'whereupon',
#  'wherever',
#  'whether',
#  'which',
#  'while',
#  'whither',
#  'who',
#  'whoever',
#  'whole',
#  'whom',
#  'whose',
#  'why',
#  'will',
#  'with',
#  'within',
#  'without',
#  'would',
#  'yet',
#  'you',
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  '‘d',
#  '‘ll',
#  '‘m',
#  '‘re',
#  '‘s',
#  '‘ve',
#  '’d',
#  '’ll',
#  '’m',
#  '’re',
#  '’s',
#  '’ve'}

# %%
tokens = []

""" Update those tokens w/o stopwords"""
for doc in tokenizer.pipe(df['reviews.text'], batch_size=500):
    
    doc_tokens = []
    
    for token in doc:
        if (token.is_stop == False) & (token.is_punct == False):
            doc_tokens.append(token.text.lower())

    tokens.append(doc_tokens)

df['tokens'] = tokens

# %%
df.tokens.head()
# Out:
# 0    [order, 3, item, bad, quality., missing, backu...
# 1               [bulk, expensive, way, products, like]
# 2                            [duracell, price, happy.]
# 3              [work, brand, batteries, better, price]
# 4            [batteries, long, lasting, price, great.]
# Name: tokens, dtype: object

# %%
wc = count(df['tokens'])

wc_top20 = wc[wc['rank'] <= 20]

squarify.plot(sizes=wc_top20['pct_total'], label=wc_top20['word'], alpha=.8 )
plt.axis('off')
plt.show()

# %% [markdown]
# ### Extending Stop Words

# %%
print(type(nlp.Defaults.stop_words))
# Out:
# <class 'set'>

# %%
STOP_WORDS = nlp.Defaults.stop_words.union(
    {'I', 'amazon', 'i', 'Amazon', 'it', "it's", 'it.', 'the', 'this','batteries'})

# %%
STOP_WORDS
# Out:
# {"'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  'Amazon',
#  'I',
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'amazon',
#  'among',
#  'amongst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'batteries',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'could',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
#  'enough',
#  'even',
#  'ever',
#  'every',
#  'everyone',
#  'everything',
#  'everywhere',
#  'except',
#  'few',
#  'fifteen',
#  'fifty',
#  'first',
#  'five',
#  'for',
#  'former',
#  'formerly',
#  'forty',
#  'four',
#  'from',
#  'front',
#  'full',
#  'further',
#  'get',
#  'give',
#  'go',
#  'had',
#  'has',
#  'have',
#  'he',
#  'hence',
#  'her',
#  'here',
#  'hereafter',
#  'hereby',
#  'herein',
#  'hereupon',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'however',
#  'hundred',
#  'i',
#  'if',
#  'in',
#  'indeed',
#  'into',
#  'is',
#  'it',
#  "it's",
#  'it.',
#  'its',
#  'itself',
#  'just',
#  'keep',
#  'last',
#  'latter',
#  'latterly',
#  'least',
#  'less',
#  'made',
#  'make',
#  'many',
#  'may',
#  'me',
#  'meanwhile',
#  'might',
#  'mine',
#  'more',
#  'moreover',
#  'most',
#  'mostly',
#  'move',
#  'much',
#  'must',
#  'my',
#  'myself',
#  "n't",
#  'name',
#  'namely',
#  'neither',
#  'never',
#  'nevertheless',
#  'next',
#  'nine',
#  'no',
#  'nobody',
#  'none',
#  'noone',
#  'nor',
#  'not',
#  'nothing',
#  'now',
#  'nowhere',
#  'n‘t',
#  'n’t',
#  'of',
#  'off',
#  'often',
#  'on',
#  'once',
#  'one',
#  'only',
#  'onto',
#  'or',
#  'other',
#  'others',
#  'otherwise',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'part',
#  'per',
#  'perhaps',
#  'please',
#  'put',
#  'quite',
#  'rather',
#  're',
#  'really',
#  'regarding',
#  'same',
#  'say',
#  'see',
#  'seem',
#  'seemed',
#  'seeming',
#  'seems',
#  'serious',
#  'several',
#  'she',
#  'should',
#  'show',
#  'side',
#  'since',
#  'six',
#  'sixty',
#  'so',
#  'some',
#  'somehow',
#  'someone',
#  'something',
#  'sometime',
#  'sometimes',
#  'somewhere',
#  'still',
#  'such',
#  'take',
#  'ten',
#  'than',
#  'that',
#  'the',
#  'their',
#  'them',
#  'themselves',
#  'then',
#  'thence',
#  'there',
#  'thereafter',
#  'thereby',
#  'therefore',
#  'therein',
#  'thereupon',
#  'these',
#  'they',
#  'third',
#  'this',
#  'those',
#  'though',
#  'three',
#  'through',
#  'throughout',
#  'thru',
#  'thus',
#  'to',
#  'together',
#  'too',
#  'top',
#  'toward',
#  'towards',
#  'twelve',
#  'twenty',
#  'two',
#  'under',
#  'unless',
#  'until',
#  'up',
#  'upon',
#  'us',
#  'used',
#  'using',
#  'various',
#  'very',
#  'via',
#  'was',
#  'we',
#  'well',
#  'were',
#  'what',
#  'whatever',
#  'when',
#  'whence',
#  'whenever',
#  'where',
#  'whereafter',
#  'whereas',
#  'whereby',
#  'wherein',
#  'whereupon',
#  'wherever',
#  'whether',
#  'which',
#  'while',
#  'whither',
#  'who',
#  'whoever',
#  'whole',
#  'whom',
#  'whose',
#  'why',
#  'will',
#  'with',
#  'within',
#  'without',
#  'would',
#  'yet',
#  'you',
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  '‘d',
#  '‘ll',
#  '‘m',
#  '‘re',
#  '‘s',
#  '‘ve',
#  '’d',
#  '’ll',
#  '’m',
#  '’re',
#  '’s',
#  '’ve'}

# %%
tokens = []

for doc in tokenizer.pipe(df['reviews.text'], batch_size=500):
    
    doc_tokens = []
    
    for token in doc: 
        if token.text.lower() not in STOP_WORDS:
            doc_tokens.append(token.text.lower())
   
    tokens.append(doc_tokens)
    
df['tokens'] = tokens

# %%
wc = count(df['tokens'])
wc.head()
# Out:
#         word  appears_in  count  rank  pct_total  cul_pct_total  \
# 73     great        7187   8183   1.0   0.023959       0.023959
# 63      good        4633   5148   2.0   0.015073       0.039032
# 7808  tablet        3920   4714   3.0   0.013802       0.052834
# 106     love        3154   3458   4.0   0.010125       0.062958
# 110      use        2881   3233   5.0   0.009466       0.072424
#
#       appears_in_pct
# 73          0.253671
# 63          0.163525
# 7808        0.138359
# 106         0.111323
# 110         0.101687

# %%
wc_top20 = wc[wc['rank'] <= 20]

squarify.plot(sizes=wc_top20['pct_total'], label=wc_top20['word'], alpha=.8 )
plt.axis('off')
plt.show()

# %%
df['reviews.rating'].value_counts()
# Out:
# 5    19897
# 4     5648
# 3     1206
# 1      965
# 2      616
# Name: reviews.rating, dtype: int64

# %%
sns.countplot(x='reviews.rating', data=df)

# %% [markdown]
# ### Statistical Trimming
#
# So far, we have talked about stop word in relation to either broad english words or domain specific stop words. Another common approach to stop word removal is via statistical trimming. The basic idea: preserve the words that give the most about of variation in your data.
#
# Do you remember this graph?

# %%
sns.lineplot(x='rank', y='cul_pct_total', data=wc);

# %% [markdown]
# This graph tells us that only a *handful* of words represented 80% of words in the overall corpus. We can interpret this in two ways:
# 1. The words that appear most frequently may not provide any insight into the mean on the documens since they are so prevalent.
# 2. Words that appear infrequeny (at the end of the graph) also probably do not add much value, because the are mentioned so rarely.
#
# Let's take a look at the words at the bottom and the top and make a decision for ourselves:

# %%
wc.tail(20)
# Out:
#                                                     word  appears_in  count  \
# 21205                                              cares           1      1
# 21207                                        photo/video           1      1
# 21206                                            taking,           1      1
# 21208                                               "t".           1      1
# 21210  say..............................................           1      1
# 21209                         kindlelishous!!!!!!!!!!!!!           1      1
# 21211                                         competent,           1      1
# 21212                                        3-year-old,           1      1
# 21213                                         dollars.my           1      1
# 21214                                             relies           1      1
# 21215                                            readi,g           1      1
# 21219                                   perfectly..great           1      1
# 21216                                           blanking           1      1
# 21217                                               app"           1      1
# 21218                                        have...then           1      1
# 21220                                             moztly           1      1
# 21221                                            titles,           1      1
# 21222                                         it..better           1      1
# 21223                                      shows/movies!           1      1
# 21224                                        bookreader.           1      1
#
#           rank  pct_total  cul_pct_total  appears_in_pct
# 21205  21206.0   0.000003       0.999945        0.000035
# 21207  21207.0   0.000003       0.999948        0.000035
# 21206  21208.0   0.000003       0.999951        0.000035
# 21208  21209.0   0.000003       0.999954        0.000035
# 21210  21210.0   0.000003       0.999957        0.000035
# 21209  21211.0   0.000003       0.999960        0.000035
# 21211  21212.0   0.000003       0.999963        0.000035
# 21212  21213.0   0.000003       0.999965        0.000035
# 21213  21214.0   0.000003       0.999968        0.000035
# 21214  21215.0   0.000003       0.999971        0.000035
# 21215  21216.0   0.000003       0.999974        0.000035
# 21219  21217.0   0.000003       0.999977        0.000035
# 21216  21218.0   0.000003       0.999980        0.000035
# 21217  21219.0   0.000003       0.999983        0.000035
# 21218  21220.0   0.000003       0.999986        0.000035
# 21220  21221.0   0.000003       0.999988        0.000035
# 21221  21222.0   0.000003       0.999991        0.000035
# 21222  21223.0   0.000003       0.999994        0.000035
# 21223  21224.0   0.000003       0.999997        0.000035
# 21224  21225.0   0.000003       1.000000        0.000035

# %%
wc['appears_in_pct'].describe()
# Out:
# count    21225.000000
# mean         0.000544
# std          0.003826
# min          0.000035
# 25%          0.000035
# 50%          0.000071
# 75%          0.000176
# max          0.253671
# Name: appears_in_pct, dtype: float64

# %%
# Frequency of appears in documents
sns.distplot(wc['appears_in_pct']);
# Out:
# /Users/jonathansokoll/anaconda3/envs/U4-S1-NLP-DS6/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(wc['appears_in_pct'])

# %%
# Tree-Map w/ Words that appear in a least 2.5% of documents. 

wc = wc[wc['appears_in_pct'] >= 0.025]

sns.distplot(wc['appears_in_pct']);

# %% [markdown]
# ## Challenge
#
# In the module project, you will apply stop word removal to a new corpus. You will focus on applying dictionary based stop word removal, but as a stretch goal, you should consider applying statistical stopword trimming.

# %% [markdown]
# # Stemming & Lemmatization (Learn)
# <a id="p3"></a>

# %% [markdown]
# ## Overview
#
# You can see from our example above there is still some normalization to do to get a clean analysis. You notice that there many words (*i.e.* 'batteries', 'battery') which share the same root word. We can use either the process of stemming or lemmatization to trim our words down to the 'root' word.
#
# __Section Agenda__:
#
# - Which is which
# - why use one v. other
# - show side by side visualizations
# - how to do it in spacy & nltk
# - introduce PoS in here as well

# %% [markdown]
# ## Follow Along

# %% [markdown]
# ### Stemming
#
# > *a process for removing the commoner morphological and inflexional endings from words in English. Its main use is as part of a term normalisation process that is usually done when setting up Information Retrieval systems.* - [Martin Porter](https://tartarus.org/martin/PorterStemmer/)
#
# Some examples include:
# - 'ing'
# - 'ed'
# - 's'
#
# These rules are by no means comprehensive, but they are somewhere to start. Most stemming is done by well documented algorithms such as Porter, Snowball, and Dawson. Porter and its newer version Snowball are the most popular stemming algorithms today. For more information on various stemming algorithms check out [*"A Comparative Study of Stemming Algorithms"*](https://pdfs.semanticscholar.org/1c0c/0fa35d4ff8a2f925eb955e48d655494bd167.pdf)
#
#
# Spacy does not do stemming out of the box, but instead uses a different technique called *lemmatization* which we will discuss in the next section. Let's turn to an antique python package `nltk` for stemming.

# %%
from nltk.stem import PorterStemmer

ps = PorterStemmer()

words = ["python", "pythoner", "pythoning", "pythoned", "pythonly"]

for word in words:
    print(ps.stem(word))
# Out:
# python
# python
# python
# python
# pythonli

# %% [markdown]
# ### Two Minute Challenge
#
# Apply the Porter stemming algorithm to the tokens in the `df` dataframe. Visualize the results in the tree graph we have been using for this session.

# %%
wc = count(df['stems'])

wc_top20 = wc[wc['rank'] <= 20]

squarify.plot(sizes=wc_top20['pct_total'], label=wc_top20['word'], alpha=.8 )
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'stems'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-134-80ad39c9fced> in <module>
# ----> 1 wc = count(df['stems'])
#       2
#       3 wc_top20 = wc[wc['rank'] <= 20]
#       4
#       5 squarify.plot(sizes=wc_top20['pct_total'], label=wc_top20['word'], alpha=.8 )
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'stems'

# %% [markdown]
# ### Lemmatization
#
# You notice immediately that results are kinda funky - words just oddly chopped off. The Porter algorithm did exactly what it knows to do: chop off endings. Stemming works well in applications where humans don't have to worry about reading the results. Search engines and more broadly information retrival algorithms use stemming. Why? Becuase it's fast.
#
# Lemmatization on the other hand is more methodical. The goal is to transform a word into's base form called a lemma. Plural nouns with funky spellings get transformed to singular tense. Verbs are all transformed to the transitive. Nice tidy data for a visualization. :) However, this tidy data can come at computational cost. Spacy does a pretty freaking good job of it though. Let's take a look:

# %%
sent = "This is the start of our NLP adventure. We started here with Spacy."

nlp = spacy.load("en_core_web_lg")

doc = nlp(sent)

# Lemma Attributes
for token in doc:
    print(token.text, "  ", token.lemma_)
    
sent = "This is the start of our NLP adventure. We started here with Spacy."
nlp = spacy.load("en_core_web_lg")
doc = nlp(sent)

for token in doc:
    # base form is called a lemma
    print(token.txt, " ", token.lemma_)
# Out:
# This    this
# is    be
# the    the
# start    start
# of    of
# our    -PRON-
# NLP    NLP
# adventure    adventure
# .    .
# We    -PRON-
# started    start
# here    here
# with    with
# Spacy    Spacy
# .    .

# %%
def get_lemmas(text):
    lemmas = []
    doc = nlp(text)
    for token in doc:
        # should filter in another function
        if ((token.is_stop==False) and (token.is_punct==False)) and (token.pos_ != 'PRON'):
            lemmas.append(token.lemma_)
    
    
    return lemmas

# %%
df['lemmas'] = df['reviews.text'].apply(get_lemmas)

# %%
df['lemmas'].head()
# Out:
# 0    [order, 3, item, bad, quality, miss, backup, s...
# 1                [bulk, expensive, way, product, like]
# 2                             [Duracell, price, happy]
# 3                  [work, brand, battery, well, price]
# 4                  [battery, long, last, price, great]
# Name: lemmas, dtype: object

# %%
wc = count(df['lemmas'])
wc_top20 = wc[wc['rank'] <= 20]

squarify.plot(sizes=wc_top20['pct_total'], label=wc_top20['word'], alpha=.8 )
plt.axis('off')
plt.show()

# %% [markdown]
# ## Challenge
#
# You should know how to apply lemmatization with Spacy to a corpus of text.

# %% [markdown]
# # Review
#
# In this module project, you've seen us apply Natural Language Processing techniques (tokenization, stopword removal, and lemmatization) to a corpus of Amazon text reviews. We analyzed those reviews using these techniques and discovered that Amazon customers are generally statisfied with the battery life of Amazon products and generally appear statisfied.
#
# You will apply similiar techniques to today's [module project assignment](LS_DS_411_Text_Data_Assignment.ipynb) to analyze coffee shop reviews from yelp. Remeber that the techniques of processing the text are just the begining. There are many ways to slice and dice the data.

# %% [markdown]
# # Sources
#
# * Spacy 101 - https://course.spacy.io
# * NLTK Book - https://www.nltk.org/book/
# * An Introduction to Information Retrieval - https://nlp.stanford.edu/IR-book/pdf/irbookonlinereading.pdf

# %% [markdown]
# ## Advanced Resources & Techniques
# - Named Entity Recognition (NER)
# - Dependcy Trees
# - Generators
# - the major libraries (NLTK, Spacy, Gensim)
